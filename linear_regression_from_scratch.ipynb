# %% [markdown]
# <a href="https://colab.research.google.com/github/nayankhanal/machine_learning_from_scratch/blob/main/linear_regression_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building Linear Regression from scratch

# %%
import numpy as np

# %%
class LinearRegression:
  def __init__(self, learning_rate=0.01, n_iterations=1000) -> None:
    self.learning_rate = learning_rate
    self.n_iterations = n_iterations

  def fit(self, X, y):
    n_features = X.shape[1]

    w = np.zeros(n_features)
    b = 0

    # initial_prediction_for_fit_line
    y_pred = X @ w + b

    mse = self.mse(y, y_pred)

  def mse(self, y, y_pred):
    mse = np.mean((y - y_pred) ** 2)
    return mse

  def gradient_descent(self):
    for i in range(self.n_iterations):
      # iterate

      # if gradient is near 0
         #  break
